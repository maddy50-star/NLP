# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sentence = "Artificial Intelligence is transforming modern technology"
print(sentence)
# Out:
# Artificial Intelligence is transforming modern technology

# %%
import nltk
nltk.download('punkt_tab')
tokens = word_tokenize(sentence)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ['Artificial', 'Intelligence', 'is', 'transforming', 'modern', 'technology']

# %%
pos_tags = pos_tag(tokens)

# %%
for word, tag in pos_tags:
    print(word, ":", tag)
# Out:
# Artificial : JJ
# Intelligence : NNP
# is : VBZ
# transforming : VBG
# modern : JJ
# technology : NN

# %%
for word, tag in pos_tags:
    if tag.startswith('NN'):
        print(word, "- Noun")
    elif tag.startswith('VB'):
        print(word, "- Verb")
    elif tag.startswith('JJ'):
        print(word, "- Adjective")
# Out:
# Artificial - Adjective
# Intelligence - Noun
# is - Verb
# transforming - Verb
# modern - Adjective
# technology - Noun

# %%
with open("pos_output.txt", "w") as file:
    for word, tag in pos_tags:
        file.write(word + " " + tag + "\n")

# %%
import nltk
nltk.download('averaged_perceptron_tagger_eng')

sentence2 = "Machine learning makes computers intelligent"
tokens2 = word_tokenize(sentence2)
pos_tags2 = pos_tag(tokens2)

for word, tag in pos_tags2:
    print(word, ":", tag)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Machine : NN
# learning : NN
# makes : VBZ
# computers : NNS
# intelligent : JJ
