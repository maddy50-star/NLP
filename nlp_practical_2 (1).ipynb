# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)

# %%
import nltk

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
text = "Natural Language Processing is very interesting and useful for building intelligent systems."
print("Original Text:\n", text)
# Out:
# Original Text:
#  Natural Language Processing is very interesting and useful for building intelligent systems.

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download the missing resource
nltk.download('punkt_tab')

tokens = word_tokenize(text)
print("\nTokens:\n", tokens)
# Out:
# Tokens:
#  ['Natural', 'Language', 'Processing', 'is', 'very', 'interesting', 'and', 'useful', 'for', 'building', 'intelligent', 'systems', '.']
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

filtered_words = []

for word in tokens:
    if word.lower() not in stop_words:
        filtered_words.append(word)

print("\nAfter Stopword Removal:\n", filtered_words)
# Out:
# After Stopword Removal:
#  ['Natural', 'Language', 'Processing', 'interesting', 'useful', 'building', 'intelligent', 'systems', '.']

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

stemmed_words = []

for word in filtered_words:
    stemmed_words.append(stemmer.stem(word))

print("\nAfter Stemming:\n", stemmed_words)
# Out:
# After Stemming:
#  ['natur', 'languag', 'process', 'interest', 'use', 'build', 'intellig', 'system', '.']

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

lemmatized_words = []

for word in filtered_words:
    lemmatized_words.append(lemmatizer.lemmatize(word))

print("\nAfter Lemmatization:\n", lemmatized_words)
# Out:
# After Lemmatization:
#  ['Natural', 'Language', 'Processing', 'interesting', 'useful', 'building', 'intelligent', 'system', '.']
