# %%
age = 21

height = 5.8

name = "Madhan"

languages = ["Python", "Java", "C++"]


coordinates = (10.5, 20.8)

# Dictionary
student = {
    "name": "Madhan",
    "age": 21,
    "course": "AI & NLP"
}

# Display values
print(age)
print(height)
print(name)
print(languages)
print(coordinates)
print(student)
# Out:
# 21
# 5.8
# Madhan
# ['Python', 'Java', 'C++']
# (10.5, 20.8)
# {'name': 'Madhan', 'age': 21, 'course': 'AI & NLP'}

# %%
marks = 85

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
else:
    print("Fail")
# Out:
# Grade B

# %%
print("Languages Known:")

for lang in languages:
    print(lang)
# Out:
# Languages Known:
# Python
# Java
# C++

# %%
count = 1

while count <= 5:
    print("Count:", count)
    count += 1
# Out:
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5

# %%
# Function to greet user
def greet(name):
    return "Hello " + name

print(greet("Madhan"))
# Out:
# Hello Madhan

# %%
def add(a, b):
    return a + b

result = add(10, 20)
print("Sum:", result)
# Out:
# Sum: 30
